# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"E:\1_Data_Science\Machine-Learning-Projects\20,Logistic_Regression_BInary_Classification\Exercise\HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)
# 2. Plot bar charts showing impact of employee salaries on retention
# 3. Plot bar charts showing corelation between department and employee retention
# 4. Now build logistic regression model using variables that were narrowed down in step 1
# 5. Measure the accuracy of the model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.groupby('left')['satisfaction_level'].mean()
# Out:
# left
# 0    0.666810
# 1    0.440098
# Name: satisfaction_level, dtype: float64

# %%
df.groupby('left')['time_spend_company'].mean()
# Out:
# left
# 0    3.380032
# 1    3.876505
# Name: time_spend_company, dtype: float64

# %%
df.corr(numeric_only=True)['left'].sort_values()
# Out:
# satisfaction_level      -0.388375
# Work_accident           -0.154622
# promotion_last_5years   -0.061788
# last_evaluation          0.006567
# number_project           0.023787
# average_montly_hours     0.071287
# time_spend_company       0.144822
# left                     1.000000
# Name: left, dtype: float64

# %%
df.boxplot(column='average_montly_hours', by='left')
# Out:
# <Axes: title={'center': 'average_montly_hours'}, xlabel='left'>

# %%
df[df.left==1].satisfaction_level.hist(alpha=0.5,
                                       color='red',
                                       label='left Company')
df[df.left==0].satisfaction_level.hist(alpha=0.5,
                                       color='blue',
                                       label='stayed')

plt.title("Satisfaction Level Distribution") 
plt.xlabel("Satisfaction Level")
plt.ylabel("Frequency") 
plt.legend()
plt.show()

# %%
df[df.left==1].satisfaction_level.hist(alpha=0.5,
                                       color='red',
                                       label='left Company')
df[df.left==0].salary.hist(alpha=0.5,
                                       color='blue',
                                       label='salary')

plt.title(" Salary vs left ") 
plt.xlabel("Left Company")
plt.ylabel("salary") 
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df[df.left==1].satisfaction_level.hist(alpha=0.5,
                                       color='red',
                                       label='left Company')
df[df.left==0].number_project.hist(alpha=0.5,
                                       color='blue',
                                       label='no of projects')

plt.title("Projects vs left") 
plt.xlabel("Projects")
plt.ylabel("number_project") 
plt.legend()
plt.show()

# %%
df[df.left==1].satisfaction_level.hist(alpha=0.5,
                                       color='red',
                                       label='left Company')
df[df.left==0].time_spend_company.hist(alpha=0.5,
                                       color='blue',
                                       label='Time spend in company')

plt.title("left company vs time spend in company") 
plt.xlabel("Satisfaction level")
plt.ylabel("time_spend_company") 
plt.legend()
plt.show()

# %% [markdown]
# **Impact of salary on employee retention**

# %%
pd.crosstab(df.salary, df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %% [markdown]
# **Department wise employee retention rate**

# %%
pd.crosstab(df.Department, df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %% [markdown]
# From above chart there seem to be some impact of department on employee retention but it is not major hence we will ignore department in our analysis
#
# <h3 style="color:white">From the data analysis so far we can conclude that we will use following variables as independant variables in our model</h3>
# <ol>
#     <li>**Satisfaction Level**</li>
#     <li>**Average Monthly Hours**</li>
#     <li>**Promotion Last 5 Years**</li>
#     <li>**Salary**</li>
# </ol>

# %%
subdf = df[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years', 'salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %% [markdown]
# Tackle salary dummy variables
#
# Salary has all text data. It needs to be converted to numbers and we will use dummy variable for that. Check my one hot encoding tutorial to understand purpose behind dummy variables.

# %%
salary_dummies = pd.get_dummies(df.salary, prefix='salary', dtype=int)

# %%
salary_dummies
# Out:
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# 1                0           0              1
# 2                0           0              1
# 3                0           1              0
# 4                0           1              0
# ...            ...         ...            ...
# 14994            0           1              0
# 14995            0           1              0
# 14996            0           1              0
# 14997            0           1              0
# 14998            0           1              0
#
# [14999 rows x 3 columns]

# %%
merged_df = pd.concat([subdf, salary_dummies], axis='columns')
merged_df.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %% [markdown]
# Now we need to remove salary column which is text data. It is already replaced by dummy variables so we can safely remove it

# %%
merged_df.drop('salary',axis='columns', inplace=True)
merged_df
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
X = merged_df
X
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0                0           1              0
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
y = df.left
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=0.3, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# **Accuracy of the model**

# %%
model.score(X_test, y_test)
# Out:
# 0.7687619047619048

# %%
# without standard scaler score 
# 0.7761904761904762

# with standard scalera
# 0.75

# %% [markdown]
# In this logistic regression, if I use less data, the model’s accuracy increases to about 76.5–76.8%, approximately 77%. However, when I apply a standard scaler function and increase the training size, the accuracy decreases. In conclusion, without scaling, this logistic regression model performs better.
